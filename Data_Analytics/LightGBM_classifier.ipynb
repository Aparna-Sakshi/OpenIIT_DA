# %%
# installing LightGBM (Required in Jupyter Notebook and  
# few other compilers once) 
# !pip install lightgbm

# %%
# Importing Required Library 
import pandas as pd 
import lightgbm as lgb 
from sklearn.model_selection import train_test_split
 
from lightgbm import LGBMClassifier

# %%
# Reading the train and test dataset 
df = pd.read_csv("train2.csv") 
df.columns
# Out:
# Index(['id', 'acousticness', 'danceability', 'energy', 'explicit',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'release_date', 'speechiness', 'tempo', 'valence', 'year',
#        'duration-min', 'popularity', 'mode*tempo', 'month', 'month_name',
#        'regression_popularity'],
#       dtype='object')

# %%
#Dropping certain columns
x=df.drop(['id','acousticness','loudness','mode','mode*tempo','key','release_date','month_name','energy','valence','popularity','regression_popularity'], axis = 1) 
y=df['regression_popularity']

# %%
# Spliiting Dataset
x_train, x_test, y_train, y_test=train_test_split(x, y)

# %%
# Creating an object for model and fitting it on training data set  
model = LGBMClassifier(num_leaves=9)
model.fit(x_train, y_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=9, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
# Predicting the Target variable 

accuracy = model.score(x_test, y_test) 
print(accuracy)
# Out:
# 0.6234870788354596

# %%
df['regression_popularity']-=1
df['rp>0']=[int(i) for i in df['regression_popularity']>0]
df['rp>1']=[int(i) for i in df['regression_popularity']>1]
df['rp>2']=[int(i) for i in df['regression_popularity']>2]
df['rp>3']=[int(i) for i in df['regression_popularity']>3]

df
# Out:
#           id  acousticness  danceability  energy  explicit  instrumentalness  \
# 0       2015        0.9490        0.2350  0.0276         0          0.927000
# 1      15901        0.8550        0.4560  0.4850         0          0.088400
# 2       9002        0.8270        0.4950  0.4990         0          0.000000
# 3       6734        0.6540        0.6430  0.4690         0          0.108000
# 4      15563        0.7380        0.7050  0.3110         0          0.000000
# ...      ...           ...           ...     ...       ...               ...
# 12222  15343        0.0408        0.8090  0.8010         0          0.000000
# 12223   1701        0.9120        0.4510  0.2400         0          0.000002
# 12224   3351        0.3280        0.5510  0.5640         0          0.002950
# 12225   8879        0.1220        0.0608  0.9390         0          0.991000
# 12226   9711        0.0380        0.3890  0.7680         1          0.000000
#
# ...

# %%
df.to_csv('train3.csv')
